timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_33', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=128, timestamp=1691168907138, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_34', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=129, timestamp=1691168908140, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_35', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=130, timestamp=1691168909141, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_36', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=131, timestamp=1691168910142, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_37', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=132, timestamp=1691168911143, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_38', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=133, timestamp=1691168912144, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_39', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ConsumerRecord(topic='mqtt-test', partition=0, offset=134, timestamp=1691168913145, timestamp_type=0, key=b'test', value=b'\x00\x00\x00\x00\x01\x0cmsg_40', headers=[('mqtt.message.id', b'0'), ('mqtt.message.qos', b'0'), ('mqtt.message.duplicate', b'false')], checksum=None, serialized_key_size=4, serialized_value_size=12, serialized_header_size=60)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for message in consumer:
#       2     print(message)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File c:\Program Files\Python311\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File c:\Program Files\Python311\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %%
for msg in consumer:
    v = avroSerde.value.deserialize(msg.value)
    k = avroSerde.key.deserialize(msg.key)
    print(msg.offset, msg.partition, k, v)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connection.py:158, in HTTPConnection._new_conn(self)
#     157 try:
# --> 158     conn = connection.create_connection(
#     159         (self._dns_host, self.port), self.timeout, **extra_kw)
#     161 except SocketTimeout as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\util\connection.py:80, in create_connection(address, timeout, source_address, socket_options)
#      79 if err is not None:
# ---> 80     raise err
#      82 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\util\connection.py:70, in create_connection(address, timeout, source_address, socket_options)
#      69     sock.bind(source_address)
# ---> 70 sock.connect(sa)
#      71 return sock
#
# OSError: [WinError 10049] The requested address is not valid in its context
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:597, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     596 # Make the request on the httplib connection object.
# --> 597 httplib_response = self._make_request(conn, method, url,
#     598                                       timeout=timeout_obj,
#     599                                       body=body, headers=headers,
#     600                                       chunked=chunked)
#     602 # If we're going to release the connection in ``finally:``, then
#     603 # the response doesn't need to know about the connection. Otherwise
#     604 # it will also try to release it and we'll have a double-release
#     605 # mess.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:354, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353 else:
# --> 354     conn.request(method, url, **httplib_request_kw)
#     356 # Reset the timeout for the recv() on the socket
#
# File c:\Program Files\Python311\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Program Files\Python311\Lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Program Files\Python311\Lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Program Files\Python311\Lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File c:\Program Files\Python311\Lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connection.py:181, in HTTPConnection.connect(self)
#     180 def connect(self):
# --> 181     conn = self._new_conn()
#     182     self._prepare_conn(conn)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connection.py:167, in HTTPConnection._new_conn(self)
#     166 except SocketError as e:
# --> 167     raise NewConnectionError(
#     168         self, "Failed to establish a new connection: %s" % e)
#     170 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001C6C3057390>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:663, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     661     log.warning("Retrying (%r) after connection "
#     662                 "broken by '%r': %s", retries, err, url)
# --> 663     return self.urlopen(method, url, body, headers, retries,
#     664                         redirect, assert_same_host,
#     665                         timeout=timeout, pool_timeout=pool_timeout,
#     666                         release_conn=release_conn, body_pos=body_pos,
#     667                         **response_kw)
#     669 def drain_and_release_conn(response):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:663, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     661     log.warning("Retrying (%r) after connection "
#     662                 "broken by '%r': %s", retries, err, url)
# --> 663     return self.urlopen(method, url, body, headers, retries,
#     664                         redirect, assert_same_host,
#     665                         timeout=timeout, pool_timeout=pool_timeout,
#     666                         release_conn=release_conn, body_pos=body_pos,
#     667                         **response_kw)
#     669 def drain_and_release_conn(response):
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 663 (2 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:663, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     661     log.warning("Retrying (%r) after connection "
#     662                 "broken by '%r': %s", retries, err, url)
# --> 663     return self.urlopen(method, url, body, headers, retries,
#     664                         redirect, assert_same_host,
#     665                         timeout=timeout, pool_timeout=pool_timeout,
#     666                         release_conn=release_conn, body_pos=body_pos,
#     667                         **response_kw)
#     669 def drain_and_release_conn(response):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:637, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     635     e = ProtocolError('Connection aborted.', e)
# --> 637 retries = retries.increment(method, url, error=e, _pool=self,
#     638                             _stacktrace=sys.exc_info()[2])
#     639 retries.sleep()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\util\retry.py:399, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     398 if new_retry.is_exhausted():
# --> 399     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     401 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='0.0.0.0', port=8081): Max retries exceeded with url: /schemas/ids/1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001C6C3057390>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\confluent_avro\schema_registry\errors.py:100, in handle_client_error.<locals>.wrapper(*args, **kwargs)
#      99 try:
# --> 100     response = func(*args, **kwargs)
#     101 except (Timeout, ReadTimeout, RequestsConnectionError) as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\confluent_avro\schema_registry\client_http.py:115, in SchemaRegistry.get_schema(self, schema_id)
#     105 """
#     106 GET /schemas/ids/(in: id)
#     107
#    (...)
#     112 :rtype: str
#     113 """
# --> 115 response = self._session.get(url=f"/schemas/ids/{schema_id}")
#     116 response.raise_for_status()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\confluent_avro\schema_registry\client_http.py:25, in SchemaRegistrySession.request(self, method, url, *args, **kwargs)
#      24 url = urljoin(self.base_url, url)
# ---> 25 return super(SchemaRegistrySession, self).request(method, url, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='0.0.0.0', port=8081): Max retries exceeded with url: /schemas/ids/1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001C6C3057390>: Failed to establish a new connection: [WinError 10049] The requested address is not valid in its context'))
#
# During handling of the above exception, another exception occurred:
#
# SchemaRegistryNetworkError                Traceback (most recent call last)
# Cell In[7], line 2
#       1 for msg in consumer:
# ----> 2     v = avroSerde.value.deserialize(msg.value)
#       3     k = avroSerde.key.deserialize(msg.key)
#       4     print(msg.offset, msg.partition, k, v)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\confluent_avro\serde.py:57, in AvroSerde.deserialize(self, data)
#      54 if magic != MAGIC_BYTE:
#      55     raise MessageParsingError("message does not start with magic byte")
# ---> 57 decoder = self._get_decoder(schema_id)
#      58 return decoder.decode(input_stream)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\confluent_avro\serde.py:84, in AvroSerde._get_decoder(self, schema_id)
#      82 if schema_id in self._decoder_map:
#      83     return self._decoder_map[schema_id]
# ---> 84 schema_str = self.sr.get_schema(schema_id)
#      85 self._decoder_map[schema_id] = avrolib.Decoder(schema_str)
#      86 return self._decoder_map[schema_id]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\confluent_avro\schema_registry\errors.py:102, in handle_client_error.<locals>.wrapper(*args, **kwargs)
#     100     response = func(*args, **kwargs)
#     101 except (Timeout, ReadTimeout, RequestsConnectionError) as e:
# --> 102     raise SchemaRegistryNetworkError(error={"message": e.__doc__})
#     103 except HTTPError as e:
#     104     client_error = ClientErrorResponse(e.response)
#
# SchemaRegistryNetworkError:

# %%
consumer.close()
